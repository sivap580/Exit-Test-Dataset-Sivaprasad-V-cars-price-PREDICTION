# %%
#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data_car.csv')

# %%
data
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# ...                                      ...          ...            ...
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity   MSRP
# 0               26        19        3916  46135
# 1               28        19        3916  40650
# 2               28        20        3916  36350
# 3               28        18        3916  29450
# 4               28        18        3916  34500
# ...            ...       ...         ...    ...
# 11909           23        16         204  46120
# 11910           23        16         204  56670
# 11911           23        16         204  50620
# 11912           23        16         204  50920
# 11913           26        17          61  28995
#
# [11914 rows x 16 columns]

# %%
data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
data.rename(columns={"Engine Fuel Type": "Engine_Fuel_Type"}, inplace=True)

# %%
data.rename(columns={"Engine HP": "Engine_HP"}, inplace=True)

# %%
data.rename(columns={"Engine Cylinders": "Engine_Cylinders"}, inplace=True)

# %%
data.rename(columns={"Transmission Type": "Transmission_Type"}, inplace=True)

# %%
data.rename(columns={"highway MPG": "highway_MPG"}, inplace=True)

# %%
data.rename(columns={"city mpg": "city_mpg"}, inplace=True)

# %%
data.shape
# Out:
# (11914, 16)

# %%
data.describe()
# Out:
#                Year    Engine_HP  Engine_Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway_MPG      city_mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# 25%       22.000000     16.000000    549.000000  2.100000e+04
# 50%       26.000000     18.000000   1385.000000  2.999500e+04
# 75%       30.000000     22.000000   2009.000000  4.223125e+04
# max      354.000000    137.000000   5657.000000  2.065902e+06

# %%
#numerical stats 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine_Fuel_Type   11911 non-null  object
#  4   Engine_HP          11845 non-null  float64
#  5   Engine_Cylinders   11884 non-null  float64
#  6   Transmission_Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway_MPG        11914 non-null  int64
#  13  city_mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.5+ MB

# %%
#missing values
data.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              69
# Engine_Cylinders       30
# Transmission_Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
#finding the correlation 
data.corr()
# Out:
#                       Year  Engine_HP  Engine_Cylinders  Number of Doors  \
# Year              1.000000   0.351794         -0.041479         0.263787
# Engine_HP         0.351794   1.000000          0.779988        -0.102713
# Engine_Cylinders -0.041479   0.779988          1.000000        -0.140088
# Number of Doors   0.263787  -0.102713         -0.140088         1.000000
# highway_MPG       0.258240  -0.406563         -0.621606         0.118570
# city_mpg          0.198171  -0.439371         -0.600776         0.120881
# Popularity        0.073049   0.037501          0.041145        -0.048272
# MSRP              0.227590   0.662008          0.531312        -0.126635
#
#                   highway_MPG  city_mpg  Popularity      MSRP
# Year                 0.258240  0.198171    0.073049  0.227590
# Engine_HP           -0.406563 -0.439371    0.037501  0.662008
# Engine_Cylinders    -0.621606 -0.600776    0.041145  0.531312
# Number of Doors      0.118570  0.120881   -0.048272 -0.126635
# highway_MPG          1.000000  0.886829   -0.020991 -0.160043
# city_mpg             0.886829  1.000000   -0.003217 -0.157676
# Popularity          -0.020991 -0.003217    1.000000 -0.048476
# MSRP                -0.160043 -0.157676   -0.048476  1.000000

# %%
data.describe(include='object').T
# Out:
#                    count unique                top  freq
# Make               11914     48          Chevrolet  1123
# Model              11914    915     Silverado 1500   156
# Engine_Fuel_Type   11911     10   regular unleaded  7172
# Transmission_Type  11914      5          AUTOMATIC  8266
# Driven_Wheels      11914      4  front wheel drive  4787
# Market Category     8172     71          Crossover  1110
# Vehicle Size       11914      3            Compact  4764
# Vehicle Style      11914     16              Sedan  3048

# %%
#columns in dataset 
data.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine_Fuel_Type', 'Engine_HP',
#        'Engine_Cylinders', 'Transmission_Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway_MPG', 'city_mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
#numerical data 
num_data= data.select_dtypes(include=['int64', 'float64']) 
num_data
# Out:
#        Year  Engine_HP  Engine_Cylinders  Number of Doors  highway_MPG  \
# 0      2011      335.0               6.0              2.0           26
# 1      2011      300.0               6.0              2.0           28
# 2      2011      300.0               6.0              2.0           28
# 3      2011      230.0               6.0              2.0           28
# 4      2011      230.0               6.0              2.0           28
# ...     ...        ...               ...              ...          ...
# 11909  2012      300.0               6.0              4.0           23
# 11910  2012      300.0               6.0              4.0           23
# 11911  2012      300.0               6.0              4.0           23
# 11912  2013      300.0               6.0              4.0           23
# 11913  2006      221.0               6.0              4.0           26
#
#        city_mpg  Popularity   MSRP
# 0            19        3916  46135
# 1            19        3916  40650
# 2            20        3916  36350
# 3            18        3916  29450
# 4            18        3916  34500
# ...         ...         ...    ...
# 11909        16         204  46120
# 11910        16         204  56670
# 11911        16         204  50620
# 11912        16         204  50920
# 11913        17          61  28995
#
# [11914 rows x 8 columns]

# %%
#categorical data 
cat_data= data.select_dtypes(include=['object'])
cat_data
# Out:
#           Make       Model                Engine_Fuel_Type Transmission_Type  \
# 0          BMW  1 Series M     premium unleaded (required)            MANUAL
# 1          BMW    1 Series     premium unleaded (required)            MANUAL
# 2          BMW    1 Series     premium unleaded (required)            MANUAL
# 3          BMW    1 Series     premium unleaded (required)            MANUAL
# 4          BMW    1 Series     premium unleaded (required)            MANUAL
# ...        ...         ...                             ...               ...
# 11909    Acura         ZDX     premium unleaded (required)         AUTOMATIC
# 11910    Acura         ZDX     premium unleaded (required)         AUTOMATIC
# 11911    Acura         ZDX     premium unleaded (required)         AUTOMATIC
# 11912    Acura         ZDX  premium unleaded (recommended)         AUTOMATIC
# 11913  Lincoln      Zephyr                regular unleaded         AUTOMATIC
#
#            Driven_Wheels                        Market Category Vehicle Size  \
# 0       rear wheel drive  Factory Tuner,Luxury,High-Performance      Compact
# 1       rear wheel drive                     Luxury,Performance      Compact
# 2       rear wheel drive                Luxury,High-Performance      Compact
# 3       rear wheel drive                     Luxury,Performance      Compact
# 4       rear wheel drive                                 Luxury      Compact
# ...                  ...                                    ...          ...
# 11909    all wheel drive             Crossover,Hatchback,Luxury      Midsize
# 11910    all wheel drive             Crossover,Hatchback,Luxury      Midsize
# 11911    all wheel drive             Crossover,Hatchback,Luxury      Midsize
# 11912    all wheel drive             Crossover,Hatchback,Luxury      Midsize
# 11913  front wheel drive                                 Luxury      Midsize
#
#        Vehicle Style
# 0              Coupe
# 1        Convertible
# 2              Coupe
# 3              Coupe
# 4        Convertible
# ...              ...
# 11909  4dr Hatchback
# 11910  4dr Hatchback
# 11911  4dr Hatchback
# 11912  4dr Hatchback
# 11913          Sedan
#
# [11914 rows x 8 columns]

# %%
#missing values
data.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              69
# Engine_Cylinders       30
# Transmission_Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
#Checking the data type
data.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine_Fuel_Type      object
# Engine_HP            float64
# Engine_Cylinders     float64
# Transmission_Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway_MPG            int64
# city_mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
#To check the unique values in all columns
for column in data.columns:
   print(f"Unique values in {column}: {data[column].nunique()}")
# Out:
# Unique values in Make: 48
# Unique values in Model: 915
# Unique values in Year: 28
# Unique values in Engine_Fuel_Type: 10
# Unique values in Engine_HP: 356
# Unique values in Engine_Cylinders: 9
# Unique values in Transmission_Type: 5
# Unique values in Driven_Wheels: 4
# Unique values in Number of Doors: 3
# Unique values in Market Category: 71
# Unique values in Vehicle Size: 3
# Unique values in Vehicle Style: 16
# Unique values in highway_MPG: 59
# Unique values in city_mpg: 69
# Unique values in Popularity: 48
# Unique values in MSRP: 6049

# %%
#clearing and filling null values of column 

mode_value = data['Engine_Cylinders'].mode().values[0]

data['Engine_Cylinders'].fillna(mode_value, inplace=True) 

mode_value = data['Engine_Fuel_Type'].mode().values[0]

data['Engine_Fuel_Type'].fillna(mode_value, inplace=True)

mode_value = data['Engine_HP'].mode().values[0]

data['Engine_HP'].fillna(mode_value, inplace=True)

mode_value = data['Number of Doors'].mode().values[0]

data['Number of Doors'].fillna(mode_value, inplace=True) 

mode_value = data['Market Category'].mode().values[0]

data['Market Category'].fillna(mode_value, inplace=True)

# %%
#missing values
data.isna().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine_Fuel_Type     0
# Engine_HP            0
# Engine_Cylinders     0
# Transmission_Type    0
# Driven_Wheels        0
# Number of Doors      0
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# highway_MPG          0
# city_mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
#boxplot 

freqgraph = data.select_dtypes(include=['float']) 
freqgraph.hist()
plt.show()

# %%
#numerical datas 
num_data= data.select_dtypes(include=['int64', 'float64']) 
num_data
# Out:
#        Year  Engine_HP  Engine_Cylinders  Number of Doors  highway_MPG  \
# 0      2011      335.0               6.0              2.0           26
# 1      2011      300.0               6.0              2.0           28
# 2      2011      300.0               6.0              2.0           28
# 3      2011      230.0               6.0              2.0           28
# 4      2011      230.0               6.0              2.0           28
# ...     ...        ...               ...              ...          ...
# 11909  2012      300.0               6.0              4.0           23
# 11910  2012      300.0               6.0              4.0           23
# 11911  2012      300.0               6.0              4.0           23
# 11912  2013      300.0               6.0              4.0           23
# 11913  2006      221.0               6.0              4.0           26
#
#        city_mpg  Popularity   MSRP
# 0            19        3916  46135
# 1            19        3916  40650
# 2            20        3916  36350
# 3            18        3916  29450
# 4            18        3916  34500
# ...         ...         ...    ...
# 11909        16         204  46120
# 11910        16         204  56670
# 11911        16         204  50620
# 11912        16         204  50920
# 11913        17          61  28995
#
# [11914 rows x 8 columns]

# %%
#categorical datas 
cat_data= data.select_dtypes(include=['object'])
cat_data
# Out:
#           Make       Model                Engine_Fuel_Type Transmission_Type  \
# 0          BMW  1 Series M     premium unleaded (required)            MANUAL
# 1          BMW    1 Series     premium unleaded (required)            MANUAL
# 2          BMW    1 Series     premium unleaded (required)            MANUAL
# 3          BMW    1 Series     premium unleaded (required)            MANUAL
# 4          BMW    1 Series     premium unleaded (required)            MANUAL
# ...        ...         ...                             ...               ...
# 11909    Acura         ZDX     premium unleaded (required)         AUTOMATIC
# 11910    Acura         ZDX     premium unleaded (required)         AUTOMATIC
# 11911    Acura         ZDX     premium unleaded (required)         AUTOMATIC
# 11912    Acura         ZDX  premium unleaded (recommended)         AUTOMATIC
# 11913  Lincoln      Zephyr                regular unleaded         AUTOMATIC
#
#            Driven_Wheels                        Market Category Vehicle Size  \
# 0       rear wheel drive  Factory Tuner,Luxury,High-Performance      Compact
# 1       rear wheel drive                     Luxury,Performance      Compact
# 2       rear wheel drive                Luxury,High-Performance      Compact
# 3       rear wheel drive                     Luxury,Performance      Compact
# 4       rear wheel drive                                 Luxury      Compact
# ...                  ...                                    ...          ...
# 11909    all wheel drive             Crossover,Hatchback,Luxury      Midsize
# 11910    all wheel drive             Crossover,Hatchback,Luxury      Midsize
# 11911    all wheel drive             Crossover,Hatchback,Luxury      Midsize
# 11912    all wheel drive             Crossover,Hatchback,Luxury      Midsize
# 11913  front wheel drive                                 Luxury      Midsize
#
#        Vehicle Style
# 0              Coupe
# 1        Convertible
# 2              Coupe
# 3              Coupe
# 4        Convertible
# ...              ...
# 11909  4dr Hatchback
# 11910  4dr Hatchback
# 11911  4dr Hatchback
# 11912  4dr Hatchback
# 11913          Sedan
#
# [11914 rows x 8 columns]

# %%
import matplotlib.pyplot as plt 
from scipy import stats

# %%
#Correlation using heatmap
plt.figure(figsize = (30, 25))
sns.heatmap(data.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
#DATA PREPROCESSING
#CONVERT ALL CATEGORICAL VALUES INTO NUMERICAL. FINDING OUTLIERS AND REMOVING THEM

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder() 

data['Make']= le.fit_transform(data['Make'])
data['Model']= le.fit_transform(data['Model'])
data['Engine_Fuel_Type']= le.fit_transform(data['Engine_Fuel_Type'])
data['Transmission_Type']= le.fit_transform(data['Transmission_Type'])
data['Driven_Wheels']= le.fit_transform(data['Driven_Wheels'])
data['Market Category']= le.fit_transform(data['Market Category']) 
data['Vehicle Size']= le.fit_transform(data['Vehicle Size'])
data['Vehicle Style']= le.fit_transform(data['Vehicle Style'])
data
# Out:
#        Make  Model  Year  Engine_Fuel_Type  Engine_HP  Engine_Cylinders  \
# 0         4      1  2011                 8      335.0               6.0
# 1         4      0  2011                 8      300.0               6.0
# 2         4      0  2011                 8      300.0               6.0
# 3         4      0  2011                 8      230.0               6.0
# 4         4      0  2011                 8      230.0               6.0
# ...     ...    ...   ...               ...        ...               ...
# 11909     0    901  2012                 8      300.0               6.0
# 11910     0    901  2012                 8      300.0               6.0
# 11911     0    901  2012                 8      300.0               6.0
# 11912     0    901  2013                 7      300.0               6.0
# 11913    25    902  2006                 9      221.0               6.0
#
#        Transmission_Type  Driven_Wheels  Number of Doors  Market Category  \
# 0                      3              3              2.0               38
# 1                      3              3              2.0               67
# 2                      3              3              2.0               64
# 3                      3              3              2.0               67
# 4                      3              3              2.0               63
# ...                  ...            ...              ...              ...
# 11909                  1              0              4.0               13
# 11910                  1              0              4.0               13
# 11911                  1              0              4.0               13
# 11912                  1              0              4.0               13
# 11913                  1              2              4.0               63
#
#        Vehicle Size  Vehicle Style  highway_MPG  city_mpg  Popularity   MSRP
# 0                 0              8           26        19        3916  46135
# 1                 0              6           28        19        3916  40650
# 2                 0              8           28        20        3916  36350
# 3                 0              8           28        18        3916  29450
# 4                 0              6           28        18        3916  34500
# ...             ...            ...          ...       ...         ...    ...
# 11909             2              2           23        16         204  46120
# 11910             2              2           23        16         204  56670
# 11911             2              2           23        16         204  50620
# 11912             2              2           23        16         204  50920
# 11913             2             14           26        17          61  28995
#
# [11914 rows x 16 columns]

# %%
#BOXPLOT

# %%
for i in data:
    sns.boxplot(x=data[i]) 
    plt.show()

# %%
#TREATING OUTLIERS

# %%
from scipy import stats

# %%
#year

# %%
IQR=stats.iqr(data.Year,interpolation='midpoint')
IQR
# Out:
# 9.0

# %%
Q1=data.Year.quantile(0.25)
Q3=data.Year.quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q1+1.5*IQR
min_limit,max_limit
# Out:
# (1993.5, 2020.5)

# %%
data.loc[data.Year>max_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine_Fuel_Type, Engine_HP, Engine_Cylinders, Transmission_Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway_MPG, city_mpg, Popularity, MSRP]
# Index: []

# %%
data.loc[data.Year<min_limit]
# Out:
#        Make  Model  Year  Engine_Fuel_Type  Engine_HP  Engine_Cylinders  \
# 17        3      2  1992                 9      172.0               6.0
# 18        3      2  1992                 9      172.0               6.0
# 19        3      2  1992                 9      172.0               6.0
# 20        3      2  1992                 9      172.0               6.0
# 21        3      2  1992                 9      172.0               6.0
# ...     ...    ...   ...               ...        ...               ...
# 11376     0    859  1993                 9      176.0               5.0
# 11377     0    859  1993                 9      176.0               5.0
# 11792    42    886  1991                 9       97.0               4.0
# 11793    42    886  1991                 9      145.0               6.0
# 11794    42    886  1991                 9      145.0               6.0
#
#        Transmission_Type  Driven_Wheels  Number of Doors  Market Category  \
# 17                     3              2              4.0               63
# 18                     3              2              4.0               63
# 19                     1              0              4.0               63
# 20                     3              2              4.0               63
# 21                     3              0              4.0               63
# ...                  ...            ...              ...              ...
# 11376                  3              2              4.0               63
# 11377                  3              2              4.0               63
# 11792                  3              2              2.0                0
# 11793                  1              2              2.0                0
# 11794                  3              0              2.0                0
#
#        Vehicle Size  Vehicle Style  highway_MPG  city_mpg  Popularity  MSRP
# 17                2             14           24        17        3105  2000
# 18                2             14           24        17        3105  2000
# 19                2             15           20        16        3105  2000
# 20                2             14           24        17        3105  2000
# 21                2             14           21        16        3105  2000
# ...             ...            ...          ...       ...         ...   ...
# 11376             2             14           24        18         204  2000
# 11377             2             14           24        18         204  2000
# 11792             0              8           29        22         640  2000
# 11793             0              8           26        18         640  2000
# 11794             0              8           23        16         640  2000
#
# [661 rows x 16 columns]

# %%
data.loc[data['Year']<min_limit, 'Year']=np.median(data.Year)

# %%
#Engine Fuel Type

# %%
IQR=stats.iqr(data.Engine_Fuel_Type,interpolation='midpoint')
IQR
# Out:
# 1.0

# %%
Q1=data.Engine_Fuel_Type.quantile(0.25)
Q3=data.Engine_Fuel_Type.quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q1+1.5*IQR
min_limit,max_limit
# Out:
# (6.5, 9.5)

# %%
data.loc[data.Engine_Fuel_Type>max_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine_Fuel_Type, Engine_HP, Engine_Cylinders, Transmission_Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway_MPG, city_mpg, Popularity, MSRP]
# Index: []

# %%
data.loc[data.Engine_Fuel_Type<min_limit]
# Out:
#        Make  Model  Year  Engine_Fuel_Type  Engine_HP  Engine_Cylinders  \
# 64       10      7  2015                 4      184.0               4.0
# 65       10      7  2015                 4      184.0               4.0
# 66       10      7  2015                 4      295.0               6.0
# 67       10      7  2015                 4      184.0               4.0
# 68       10      7  2015                 4      184.0               4.0
# ...     ...    ...   ...               ...        ...               ...
# 11874    15    893  2016                 4      355.0               8.0
# 11876    15    893  2017                 4      355.0               8.0
# 11877    15    893  2017                 4      355.0               8.0
# 11879    15    893  2017                 4      355.0               8.0
# 11880    15    893  2017                 4      355.0               8.0
#
#        Transmission_Type  Driven_Wheels  Number of Doors  Market Category  \
# 64                     1              2              4.0               41
# 65                     1              2              4.0               41
# 66                     1              0              4.0               48
# 67                     1              2              4.0               41
# 68                     1              2              4.0               48
# ...                  ...            ...              ...              ...
# 11874                  1              1              4.0               48
# 11876                  1              3              4.0               48
# 11877                  1              1              4.0               48
# 11879                  1              1              4.0               48
# 11880                  1              3              4.0               48
#
#        Vehicle Size  Vehicle Style  highway_MPG  city_mpg  Popularity   MSRP
# 64                2             14           36        23        1013  25170
# 65                2             14           36        23        1013  23950
# 66                2             14           29        18        1013  29370
# 67                2             14           36        23        1013  21995
# 68                2             14           36        23        1013  26625
# ...             ...            ...          ...       ...         ...    ...
# 11874             1              3           22        16         549  60000
# 11876             1              3           23        16         549  57315
# 11877             1              3           22        16         549  51530
# 11879             1              3           22        16         549  60315
# 11880             1              3           23        16         549  48530
#
# [1207 rows x 16 columns]

# %%
data.loc[data['Engine_Fuel_Type']<min_limit, 'Engine_Fuel_Type']=np.median(data.Engine_Fuel_Type)

# %%
#Engine_HP

# %%
IQR=stats.iqr(data.Engine_HP,interpolation='midpoint')
IQR
# Out:
# 130.0

# %%
Q1=data.Engine_HP.quantile(0.25)
Q3=data.Engine_HP.quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q1+1.5*IQR
min_limit,max_limit
# Out:
# (-25.0, 365.0)

# %%
data.loc[data.Engine_HP>max_limit]
# Out:
#        Make  Model  Year  Engine_Fuel_Type  Engine_HP  Engine_Cylinders  \
# 294      13     22  2002                 8      400.0               8.0
# 295      13     22  2002                 8      400.0               8.0
# 296      13     22  2002                 8      400.0               8.0
# 297      13     22  2002                 8      400.0               8.0
# 298      13     22  2003                 8      400.0               8.0
# ...     ...    ...   ...               ...        ...               ...
# 11875    15    893  2017                 7      420.0               8.0
# 11878    15    893  2017                 7      420.0               8.0
# 11903     4    900  2001                 8      394.0               8.0
# 11904     4    900  2002                 8      394.0               8.0
# 11905     4    900  2003                 8      394.0               8.0
#
#        Transmission_Type  Driven_Wheels  Number of Doors  Market Category  \
# 294                    3              3              2.0               30
# 295                    3              3              2.0               30
# 296                    0              3              2.0               30
# 297                    0              3              2.0               30
# 298                    3              3              2.0               30
# ...                  ...            ...              ...              ...
# 11875                  1              1              4.0               69
# 11878                  1              3              4.0               69
# 11903                  3              3              2.0               32
# 11904                  3              3              2.0               32
# 11905                  3              3              2.0               32
#
#        Vehicle Size  Vehicle Style  highway_MPG  city_mpg  Popularity    MSRP
# 294               0              6           15        10        2774  160829
# 295               0              8           15        10        2774  140615
# 296               0              8           15        10        2774  150694
# 297               0              6           15        10        2774  170829
# 298               0              6           15        10        2774  165986
# ...             ...            ...          ...       ...         ...     ...
# 11875             1              3           20        15         549   68965
# 11878             1              3           22        15         549   65965
# 11903             0              6           19        12        3916  128000
# 11904             0              6           19        12        3916  130000
# 11905             0              6           19        12        3916  131500
#
# [1422 rows x 16 columns]

# %%
data.loc[data.Engine_HP<min_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine_Fuel_Type, Engine_HP, Engine_Cylinders, Transmission_Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway_MPG, city_mpg, Popularity, MSRP]
# Index: []

# %%
data.loc[data['Engine_HP']<min_limit, 'Engine_HP']=np.median(data.Engine_HP)

# %%
#Engine_Cylinders

# %%
IQR=stats.iqr(data.Engine_Cylinders,interpolation='midpoint')
IQR
# Out:
# 2.0

# %%
Q1=data.Engine_Cylinders.quantile(0.25)
Q3=data.Engine_Cylinders.quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q1+1.5*IQR
min_limit,max_limit
# Out:
# (1.0, 7.0)

# %%
data.loc[data.Engine_Cylinders>max_limit]
# Out:
#        Make  Model  Year  Engine_Fuel_Type  Engine_HP  Engine_Cylinders  \
# 294      13     22  2002                 8      400.0               8.0
# 295      13     22  2002                 8      400.0               8.0
# 296      13     22  2002                 8      400.0               8.0
# 297      13     22  2002                 8      400.0               8.0
# 298      13     22  2003                 8      400.0               8.0
# ...     ...    ...   ...               ...        ...               ...
# 11879    15    893  2017                 9      355.0               8.0
# 11880    15    893  2017                 9      355.0               8.0
# 11903     4    900  2001                 8      394.0               8.0
# 11904     4    900  2002                 8      394.0               8.0
# 11905     4    900  2003                 8      394.0               8.0
#
#        Transmission_Type  Driven_Wheels  Number of Doors  Market Category  \
# 294                    3              3              2.0               30
# 295                    3              3              2.0               30
# 296                    0              3              2.0               30
# 297                    0              3              2.0               30
# 298                    3              3              2.0               30
# ...                  ...            ...              ...              ...
# 11879                  1              1              4.0               48
# 11880                  1              3              4.0               48
# 11903                  3              3              2.0               32
# 11904                  3              3              2.0               32
# 11905                  3              3              2.0               32
#
#        Vehicle Size  Vehicle Style  highway_MPG  city_mpg  Popularity    MSRP
# 294               0              6           15        10        2774  160829
# 295               0              8           15        10        2774  140615
# 296               0              8           15        10        2774  150694
# 297               0              6           15        10        2774  170829
# 298               0              6           15        10        2774  165986
# ...             ...            ...          ...       ...         ...     ...
# 11879             1              3           22        16         549   60315
# 11880             1              3           23        16         549   48530
# 11903             0              6           19        12        3916  128000
# 11904             0              6           19        12        3916  130000
# 11905             0              6           19        12        3916  131500
#
# [2332 rows x 16 columns]

# %%
data.loc[data.Engine_Cylinders<min_limit]
# Out:
#       Make  Model  Year  Engine_Fuel_Type  Engine_HP  Engine_Cylinders  \
# 539     12     39  2015                 9      200.0               0.0
# 540     12     39  2016                 9      200.0               0.0
# 541     12     39  2017                 9      200.0               0.0
# 1680    31    133  2015                 9      177.0               0.0
# 1681    31    133  2016                 9      177.0               0.0
# 1682    31    133  2017                 9      177.0               0.0
# 4705    18    354  2013                 9      200.0               0.0
# 4706    18    354  2014                 9      200.0               0.0
# 4785    14    359  2015                 9      200.0               0.0
# 4789    14    359  2016                 9      200.0               0.0
# 4798    14    359  2017                 9      200.0               0.0
# 5790     4    907  2015                 9      170.0               0.0
# 5791     4    907  2016                 9      170.0               0.0
# 5792     4    907  2017                 9      170.0               0.0
# 5793     4    907  2017                 9      170.0               0.0
# 6385    33    495  2014                 9      200.0               0.0
# 6386    33    495  2014                 9      200.0               0.0
# 6387    33    495  2014                 9      200.0               0.0
# 6388    33    495  2015                 9      200.0               0.0
# 6389    33    495  2015                 9      200.0               0.0
# 6390    33    495  2015                 9      200.0               0.0
# 6391    33    495  2015                 9      200.0               0.0
# 6392    33    495  2016                 9      200.0               0.0
# 6393    33    495  2016                 9      200.0               0.0
# 6394    33    495  2016                 9      200.0               0.0
# 6921    44    555  2014                 9      200.0               0.0
# 6922    44    555  2014                 9      200.0               0.0
# 6923    44    555  2014                 9      200.0               0.0
# 6924    44    555  2014                 9      200.0               0.0
# 6925    44    555  2015                 9      200.0               0.0
# 6926    44    555  2015                 9      200.0               0.0
# 6927    44    555  2015                 9      200.0               0.0
# 6928    44    555  2015                 9      200.0               0.0
# 6929    44    555  2015                 9      200.0               0.0
# 6930    44    555  2016                 9      200.0               0.0
# 6931    44    555  2016                 9      200.0               0.0
# 6932    44    555  2016                 9      200.0               0.0
# 6933    44    555  2016                 9      200.0               0.0
# 6934    44    555  2016                 9      200.0               0.0
# 6935    44    555  2016                 9      200.0               0.0
# 6936    44    555  2016                 9      200.0               0.0
# 6937    44    555  2016                 9      200.0               0.0
# 6938    44    555  2016                 9      200.0               0.0
# 8374    45    639  2013                 9      200.0               0.0
# 8375    45    639  2014                 9      200.0               0.0
# 9850    21    768  2015                 9      200.0               0.0
# 9851    21    768  2015                 9      200.0               0.0
# 9852    21    768  2016                 9      200.0               0.0
# 9853    21    768  2016                 9      200.0               0.0
# 9854    21    768  2016                 9      200.0               0.0
# 9867     9    770  2014                 9      140.0               0.0
# 9868     9    770  2014                 9      140.0               0.0
# 9869     9    770  2015                 9      140.0               0.0
# 9870     9    770  2015                 9      140.0               0.0
# 9871     9    770  2016                 9      140.0               0.0
# 9872     9    770  2016                 9      140.0               0.0
#
#       Transmission_Type  Driven_Wheels  Number of Doors  Market Category  \
# 539                   2              2              2.0               50
# 540                   2              2              2.0               50
# 541                   2              2              2.0               50
# 1680                  2              2              4.0               57
# 1681                  2              2              4.0               57
# 1682                  2              2              4.0               57
# 4705                  2              2              4.0               50
# 4706                  2              2              4.0               50
# 4785                  2              2              4.0               50
# 4789                  2              2              4.0               50
# 4798                  2              2              4.0               50
# 5790                  2              3              4.0               57
# 5791                  2              3              4.0               57
# 5792                  2              3              4.0               57
# 5793                  2              3              4.0               57
# 6385                  2              2              4.0               50
# 6386                  2              2              4.0               50
# 6387                  2              2              4.0               50
# 6388                  2              2              4.0               50
# 6389                  2              2              4.0               50
# 6390                  2              2              4.0               50
# 6391                  2              2              4.0               50
# 6392                  2              2              4.0               50
# 6393                  2              2              4.0               50
# 6394                  2              2              4.0               50
# 6921                  2              3              4.0               30
# 6922                  2              3              4.0               35
# 6923                  2              0              4.0               30
# 6924                  2              3              4.0               30
# 6925                  2              3              4.0               35
# 6926                  2              0              4.0               35
# 6927                  2              0              4.0               30
# 6928                  2              0              4.0               30
# 6929                  2              3              4.0               35
# 6930                  2              0              4.0               35
# 6931                  2              0              4.0               35
# 6932                  2              0              4.0               30
# 6933                  2              3              4.0               35
# 6934                  2              0              4.0               35
# 6935                  2              0              4.0               35
# 6936                  2              0              4.0               30
# 6937                  2              0              4.0               30
# 6938                  2              3              4.0               35
# 8374                  2              2              4.0                0
# 8375                  2              2              4.0                0
# 9850                  2              2              4.0                0
# 9851                  2              2              4.0                0
# 9852                  2              2              4.0                0
# 9853                  2              2              4.0                0
# 9854                  2              2              4.0                0
# 9867                  2              2              4.0               50
# 9868                  2              2              4.0               50
# 9869                  2              2              4.0               50
# 9870                  2              2              4.0               50
# 9871                  2              2              4.0               50
# 9872                  2              2              4.0               50
#
#       Vehicle Size  Vehicle Style  highway_MPG  city_mpg  Popularity    MSRP
# 539              0              0          108       122         819   31800
# 540              0              0          103       121         819   31800
# 541              0              0          103       121         819   31800
# 1680             0              2           82        85         617   41450
# 1681             0              2           82        85         617   41450
# 1682             0              2           82        85         617   39900
# 4705             0              2          105       132        2202   36625
# 4706             0              2          105       132        2202   36625
# 4785             0              2           99       110        5657   29170
# 4789             0              2           99       110        5657   29170
# 4798             0              2           99       110        5657   29120
# 5790             0              2          111       137        3916   42400
# 5791             0              2          111       137        3916   42400
# 5792             0              2          111       137        3916   42400
# 5793             0              2          106       129        3916   43600
# 6385             0              2          101       126        2009   35020
# 6386             0              2          101       126        2009   32000
# 6387             0              2          101       126        2009   28980
# 6388             0              2          101       126        2009   32100
# 6389             0              2          101       126        2009   35120
# 6390             0              2          101       126        2009   29010
# 6391             0              2          101       126        2009   32000
# 6392             0              2          101       126        2009   29010
# 6393             0              2          101       124        2009   34200
# 6394             0              2          101       124        2009   36790
# 6921             1             14           90        88        1391   79900
# 6922             1             14           97        94        1391   69900
# 6923             1             14           94        86        1391  104500
# 6924             1             14           90        88        1391   93400
# 6925             1             14           97        94        1391   69900
# 6926             1             14          102       101        1391   75000
# 6927             1             14          106        95        1391   85000
# 6928             1             14           98        89        1391  105000
# 6929             1             14           90        88        1391   80000
# 6930             1             14          105       102        1391   79500
# 6931             1             14          101        98        1391   66000
# 6932             1             14          105        92        1391  134500
# 6933             1             14          100        97        1391   74500
# 6934             1             14          107       101        1391   71000
# 6935             1             14          102       101        1391   75000
# 6936             1             14          107       101        1391   89500
# 6937             1             14          100        91        1391  112000
# 6938             1             14           90        88        1391   70000
# 8374             2              3           74        78        2031   49800
# 8375             2              3           74        78        2031   49800
# 9850             0             15           92       120        1720   35700
# 9851             0             15           92       120        1720   33700
# 9852             0             15           92       120        1720   33950
# 9853             0             15           92       120        1720   31950
# 9854             0             15           92       120        1720   35950
# 9867             0              2          109       128        1385   26685
# 9868             0              2          109       128        1385   27010
# 9869             0              2          109       128        1385   25170
# 9870             0              2          109       128        1385   25560
# 9871             0              2          109       128        1385   25510
# 9872             0              2          109       128        1385   25120

# %%
data.loc[data['Engine_Cylinders']<min_limit, 'Engine_Cylinders']=np.median(data.Engine_Cylinders)

# %%
data.loc[data['Engine_Cylinders']>max_limit, 'Engine_Cylinders']=np.median(data.Engine_Cylinders)

# %%
#city_mpg

# %%
IQR=stats.iqr(data.city_mpg,interpolation='midpoint')
IQR
# Out:
# 6.0

# %%
Q1=data.city_mpg.quantile(0.25)
Q3=data.city_mpg.quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q1+1.5*IQR
min_limit,max_limit
# Out:
# (7.0, 25.0)

# %%
data.loc[data.city_mpg>max_limit]
# Out:
#        Make  Model  Year  Engine_Fuel_Type  Engine_HP  Engine_Cylinders  \
# 32       12      3  2017                 7      160.0               4.0
# 33       12      3  2017                 7      160.0               4.0
# 34       12      3  2017                 7      160.0               4.0
# 87       33      8  1996                 9      115.0               4.0
# 88       33      8  1996                 9      115.0               4.0
# ...     ...    ...   ...               ...        ...               ...
# 11827    45    891  2017                 9      106.0               4.0
# 11828    45    891  2017                 9      106.0               4.0
# 11829    45    891  2017                 9      106.0               4.0
# 11830    45    891  2017                 9      106.0               4.0
# 11831    45    891  2017                 9      106.0               4.0
#
#        Transmission_Type  Driven_Wheels  Number of Doors  Market Category  \
# 32                     3              3              2.0               69
# 33                     3              3              2.0               69
# 34                     3              3              2.0               69
# 87                     3              2              2.0                0
# 88                     3              2              2.0                0
# ...                  ...            ...              ...              ...
# 11827                  3              2              2.0               50
# 11828                  1              2              4.0               50
# 11829                  1              2              4.0               50
# 11830                  1              2              4.0               50
# 11831                  3              2              4.0               50
#
#        Vehicle Size  Vehicle Style  highway_MPG  city_mpg  Popularity   MSRP
# 32                0              6           35        26         819  27495
# 33                0              6           35        26         819  24995
# 34                0              6           35        26         819  28195
# 87                0              8           36        26        2009   2000
# 88                0              8           36        26        2009   2000
# ...             ...            ...          ...       ...         ...    ...
# 11827             0              0           36        30        2031  15250
# 11828             0              2           35        30        2031  16375
# 11829             0              2           35        30        2031  17285
# 11830             0              2           35        30        2031  18000
# 11831             0              2           36        30        2031  17200
#
# [1321 rows x 16 columns]

# %%
data.loc[data.Year<min_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine_Fuel_Type, Engine_HP, Engine_Cylinders, Transmission_Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway_MPG, city_mpg, Popularity, MSRP]
# Index: []

# %%
data.loc[data['city_mpg']>max_limit, 'city_mpg']=np.median(data.city_mpg)

# %%
#highway_MPG

# %%
IQR=stats.iqr(data.highway_MPG,interpolation='midpoint')
IQR
# Out:
# 8.0

# %%
Q1=data.highway_MPG.quantile(0.25)
Q3=data.highway_MPG.quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q1+1.5*IQR
min_limit,max_limit
# Out:
# (10.0, 34.0)

# %%
data.loc[data.highway_MPG<min_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine_Fuel_Type, Engine_HP, Engine_Cylinders, Transmission_Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway_MPG, city_mpg, Popularity, MSRP]
# Index: []

# %%
data.loc[data.highway_MPG>max_limit]
# Out:
#        Make  Model  Year  Engine_Fuel_Type  Engine_HP  Engine_Cylinders  \
# 32       12      3  2017                 7      160.0               4.0
# 33       12      3  2017                 7      160.0               4.0
# 34       12      3  2017                 7      160.0               4.0
# 41        4      6  2016                 8      240.0               4.0
# 44        4      6  2016                 8      240.0               4.0
# ...     ...    ...   ...               ...        ...               ...
# 11827    45    891  2017                 9      106.0               4.0
# 11828    45    891  2017                 9      106.0               4.0
# 11829    45    891  2017                 9      106.0               4.0
# 11830    45    891  2017                 9      106.0               4.0
# 11831    45    891  2017                 9      106.0               4.0
#
#        Transmission_Type  Driven_Wheels  Number of Doors  Market Category  \
# 32                     3              3              2.0               69
# 33                     3              3              2.0               69
# 34                     3              3              2.0               69
# 41                     1              3              2.0               67
# 44                     1              0              2.0               67
# ...                  ...            ...              ...              ...
# 11827                  3              2              2.0               50
# 11828                  1              2              4.0               50
# 11829                  1              2              4.0               50
# 11830                  1              2              4.0               50
# 11831                  3              2              4.0               50
#
#        Vehicle Size  Vehicle Style  highway_MPG  city_mpg  Popularity   MSRP
# 32                0              6           35        18         819  27495
# 33                0              6           35        18         819  24995
# 34                0              6           35        18         819  28195
# 41                0              8           35        23        3916  32850
# 44                0              8           35        23        3916  34850
# ...             ...            ...          ...       ...         ...    ...
# 11827             0              0           36        18        2031  15250
# 11828             0              2           35        18        2031  16375
# 11829             0              2           35        18        2031  17285
# 11830             0              2           35        18        2031  18000
# 11831             0              2           36        18        2031  17200
#
# [1309 rows x 16 columns]

# %%
data.loc[data['highway_MPG']>max_limit, 'highway_MPG']=np.median(data.highway_MPG)

# %%
#outliers treated 

for i in data:
    sns.boxplot(x=data[i]) 
    plt.show()

# %%
##one hot encoding

# %%
data= pd.get_dummies(data)

# %%
data
# Out:
#        Make  Model  Year  Engine_Fuel_Type  Engine_HP  Engine_Cylinders  \
# 0         4      1  2011                 8      335.0               6.0
# 1         4      0  2011                 8      300.0               6.0
# 2         4      0  2011                 8      300.0               6.0
# 3         4      0  2011                 8      230.0               6.0
# 4         4      0  2011                 8      230.0               6.0
# ...     ...    ...   ...               ...        ...               ...
# 11909     0    901  2012                 8      300.0               6.0
# 11910     0    901  2012                 8      300.0               6.0
# 11911     0    901  2012                 8      300.0               6.0
# 11912     0    901  2013                 7      300.0               6.0
# 11913    25    902  2006                 9      221.0               6.0
#
#        Transmission_Type  Driven_Wheels  Number of Doors  Market Category  \
# 0                      3              3              2.0               38
# 1                      3              3              2.0               67
# 2                      3              3              2.0               64
# 3                      3              3              2.0               67
# 4                      3              3              2.0               63
# ...                  ...            ...              ...              ...
# 11909                  1              0              4.0               13
# 11910                  1              0              4.0               13
# 11911                  1              0              4.0               13
# 11912                  1              0              4.0               13
# 11913                  1              2              4.0               63
#
#        Vehicle Size  Vehicle Style  highway_MPG  city_mpg  Popularity   MSRP
# 0                 0              8           26        19        3916  46135
# 1                 0              6           28        19        3916  40650
# 2                 0              8           28        20        3916  36350
# 3                 0              8           28        18        3916  29450
# 4                 0              6           28        18        3916  34500
# ...             ...            ...          ...       ...         ...    ...
# 11909             2              2           23        16         204  46120
# 11910             2              2           23        16         204  56670
# 11911             2              2           23        16         204  50620
# 11912             2              2           23        16         204  50920
# 11913             2             14           26        17          61  28995
#
# [11914 rows x 16 columns]

# %%
y = data['MSRP'] 
x = data.drop(['MSRP'], axis =1)

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# scaling data

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
#LinearRegression

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train, y_train)
# Out:
# 0.4895403784959681

# %%
lr.score(x_test, y_test)
# Out:
# 0.6149155678038342

# %%
#Lasso Regression

# %%
from sklearn.linear_model import Lasso, LassoCV

# %%
lassocv = LassoCV(alphas = None, cv = 10, max_iter = 10000, normalize = True)
lassocv.fit(x_train, y_train)
# Out:
# C:\Users\sivap\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# LassoCV(cv=10, max_iter=10000, normalize=True)

# %%
lasso = Lasso(alpha = lassocv.alpha_)
lasso.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.4153585244690488)

# %%
lasso.score(x_train, y_train)
# Out:
# 0.4895403765823121

# %%
lasso.score(x_test, y_test)
# Out:
# 0.614923205889209

# %%
#Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dtr = DecisionTreeRegressor()
dtr.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtr.score(x_train, y_train)
# Out:
# 0.9939335936329117

# %%
dtr.score(x_test, y_test)
# Out:
# 0.955853237554479

# %%
#Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor()
rfr.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rfr.score(x_train, y_train)
# Out:
# 0.9811813870849369

# %%
rfr.score(x_test, y_test)
# Out:
# 0.9604512907965101

# %%
#best is acheived in Random Forest Regression
